# %% [markdown]
# ## Attention Projections

# %% [markdown]
# ### Check CUDA is Available

# %%
# check CUDA available
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA device count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"Current device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA available: True
# CUDA device count: 2
# Current device: 0
# Device name: NVIDIA GeForce RTX 2080 Ti

# %% [markdown]
# ### Import Necessary Libraries

# %%
import random
import nltk

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
from transformers import T5Tokenizer, T5ForConditionalGeneration
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score, confusion_matrix, classification_report
from bert_score import score as bert_score
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
import matplotlib.pyplot as plt
import torchmetrics

from model_projections import (
    FeatureProjector,
    MultitaskModelWithProjection,
    ProjectionExperimentDataset,
    create_experiment_pipeline,
    evaluate_with_sampling,
    train,
    train_and_validate_model_with_meteor_rouge,
    train_and_validate_model_with_meteor_stopping,
    METEOREarlyStopping,
    display_generated_texts,
    print_test_evaluation,
    compute_rougeL
)

# %% [markdown]
# ### Set Random Seed for Reproducibility

# %%
random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

# %% [markdown]
# ### Import Dataset

# %%
mwr_df = pd.read_csv('mwr.csv')

# %%
print(mwr_df.columns)
# Out:
# Index(['Examination ID', 'Conclusion', 'r:Th', 'Weight', 'Height',
#        'Ambient temperature', 'r:AgeInYears', 'Mammary diameter', 'Cycle',
#        'Day from the first day', 'Hormonal medications',
#        'Cancer family history', 'Breast operations', 'Num of pregnancies',
#        'R1 int', 'L1 int', 'R2 int', 'L2 int', 'R3 int', 'L3 int', 'R4 int',
#        'L4 int', 'R5 int', 'L5 int', 'R6 int', 'L6 int', 'R7 int', 'L7 int',
#        'R8 int', 'L8 int', 'R9 int', 'L9 int', 'T1 int', 'T2 int', 'R0 int',
#        'L0 int', 'R1 sk', 'L1 sk', 'R2 sk', 'L2 sk', 'R3 sk', 'L3 sk', 'R4 sk',
#        'L4 sk', 'R5 sk', 'L5 sk', 'R6 sk', 'L6 sk', 'R7 sk', 'L7 sk', 'R8 sk',
#        'L8 sk', 'R9 sk', 'L9 sk', 'T1 sk', 'T2 sk', 'R0 sk', 'L0 sk',
#        'Conclusion (Tr)', 'y_binary'],
#       dtype='object')

# %%
# Select feature columns (temperature readings)
feature_cols = [col for col in mwr_df.columns if col.endswith('int') or col.endswith('sk')]
mwr_df['features'] = mwr_df[feature_cols].values.tolist()

# Prepare labels and text targets (binary classification)
mwr_df['class_label'] = mwr_df['y_binary'].astype(int)
mwr_df['synthetic_description'] = mwr_df['Conclusion (Tr)']

# %% [markdown]
# ### Split Data into Test and Train

# %%
# 70% training, 15% validation, 15% testing

# Stratified split on 'r:Th' column
train_df, temp_df = train_test_split(
    mwr_df, 
    test_size=0.3, 
    random_state=42, 
    stratify=mwr_df['r:Th']
)

val_df, test_df = train_test_split(
    temp_df, 
    test_size=0.5, 
    random_state=42, 
    stratify=temp_df['r:Th']
)

# %%
# check class distribution
print(mwr_df['class_label'].value_counts(normalize=True))
# Out:
# class_label
# 1    0.758215
# 0    0.241785
# Name: proportion, dtype: float64

# %% [markdown]
# ## Cross Attention and Full Text

# %% [markdown]
# ### Initialise Model

# %%
tokenizer, train_loader, val_loader, test_loader, model, optimizer, device = create_experiment_pipeline(
    train_df, val_df, test_df,
    projection_mode='attention',         
    projection_type='attention',         
    use_minimal_text=False,          
    batch_size=32,
    learning_rate=5e-5
)
# Out:
# ============================================================
# EXPERIMENT: ATTENTION projection + FULL text
# Projection type: attention
# ============================================================
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Using device: cuda
# Model configuration:
#   Projection mode: attention
#   Projection type: attention
#   Minimal text: False
#   Feature projection: Yes

# %% [markdown]
# ### Train Model

# %%
best_accuracy, best_f1, best_auc, best_meteor, best_rougeL = train_and_validate_model_with_meteor_rouge(
    model, train_loader, val_loader, optimizer, device, tokenizer, num_epochs=50, meteor_every=1
)
# Out:
# Epoch 1/50
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Training loss: 18.4092
# Classification loss: 0.7482
# Generation loss: 1.8334
# Weighted gen loss: 18.334368
# Validation loss: 10.5718
# Validation metrics:
#   Accuracy     : 0.7552
#   F1-Score     : 0.6994
#   Sensitivity  : 0.9530
#   Specificity  : 0.1357
#   AUC-ROC      : 0.6531
#
# --- Text Evaluation (Epoch 1) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4130
#   ✓ New best METEOR: 0.4130
#   ROUGE-L F1   : 0.4143
#   ✓ New best ROUGE-L F1: 0.4143
# ✓ New best accuracy: 0.7552
# ✓ New best F1: 0.6994
# ✓ New best AUC-ROC: 0.6531
#
# Epoch 2/50
# Training loss: 11.2060
# Classification loss: 0.5596
# Generation loss: 1.1150
# Weighted gen loss: 11.150090
# Validation loss: 9.1924
# Validation metrics:
#   Accuracy     : 0.7591
#   F1-Score     : 0.7320
#   Sensitivity  : 0.9134
#   Specificity  : 0.2759
#   AUC-ROC      : 0.7081
#
# --- Text Evaluation (Epoch 2) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4216
#   ✓ New best METEOR: 0.4216
#   ROUGE-L F1   : 0.4149
#   ✓ New best ROUGE-L F1: 0.4149
# ✓ New best accuracy: 0.7591
# ✓ New best F1: 0.7320
# ✓ New best AUC-ROC: 0.7081
#
# Epoch 3/50
# Training loss: 10.0540
# Classification loss: 0.5375
# Generation loss: 1.0000
# Weighted gen loss: 10.000251
# Validation loss: 8.6149
# Validation metrics:
#   Accuracy     : 0.7701
#   F1-Score     : 0.7393
#   Sensitivity  : 0.9301
#   Specificity  : 0.2691
#   AUC-ROC      : 0.7200
#
# --- Text Evaluation (Epoch 3) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4222
#   ✓ New best METEOR: 0.4222
#   ROUGE-L F1   : 0.4147
# ✓ New best accuracy: 0.7701
# ✓ New best F1: 0.7393
# ✓ New best AUC-ROC: 0.7200
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 4/50
# Training loss: 9.4692
# Classification loss: 0.5272
# Generation loss: 0.9416
# Weighted gen loss: 9.416450
# Validation loss: 8.2531
# Validation metrics:
#   Accuracy     : 0.7594
#   F1-Score     : 0.7451
#   Sensitivity  : 0.8857
#   Specificity  : 0.3637
#   AUC-ROC      : 0.7423
#
# --- Text Evaluation (Epoch 4) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4224
#   ✓ New best METEOR: 0.4224
#   ROUGE-L F1   : 0.4145
# ✓ New best F1: 0.7451
# ✓ New best AUC-ROC: 0.7423
#
# Epoch 5/50
# Training loss: 9.0794
# Classification loss: 0.5217
# Generation loss: 0.9027
# Weighted gen loss: 9.027204
# Validation loss: 8.0097
# Validation metrics:
#   Accuracy     : 0.7627
#   F1-Score     : 0.7573
#   Sensitivity  : 0.8628
#   Specificity  : 0.4493
#   AUC-ROC      : 0.7505
#
# --- Text Evaluation (Epoch 5) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4188
#   ROUGE-L F1   : 0.4091
# ✓ New best F1: 0.7573
# ✓ New best AUC-ROC: 0.7505
#
# Epoch 6/50
# Training loss: 8.7607
# Classification loss: 0.5146
# Generation loss: 0.8709
# Weighted gen loss: 8.709228
# Validation loss: 7.8542
# Validation metrics:
#   Accuracy     : 0.7699
#   F1-Score     : 0.7583
#   Sensitivity  : 0.8868
#   Specificity  : 0.4036
#   AUC-ROC      : 0.7566
#
# --- Text Evaluation (Epoch 6) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4142
#   ROUGE-L F1   : 0.4072
# ✓ New best F1: 0.7583
# ✓ New best AUC-ROC: 0.7566
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 7/50
# Training loss: 8.5120
# Classification loss: 0.5083
# Generation loss: 0.8461
# Weighted gen loss: 8.461170
# Validation loss: 7.6835
# Validation metrics:
#   Accuracy     : 0.7594
#   F1-Score     : 0.7531
#   Sensitivity  : 0.8631
#   Specificity  : 0.4344
#   AUC-ROC      : 0.7611
#
# --- Text Evaluation (Epoch 7) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4175
#   ROUGE-L F1   : 0.4088
# ✓ New best AUC-ROC: 0.7611
#
# Epoch 8/50
# Training loss: 8.3147
# Classification loss: 0.5078
# Generation loss: 0.8264
# Weighted gen loss: 8.263936
# Validation loss: 7.5575
# Validation metrics:
#   Accuracy     : 0.7643
#   F1-Score     : 0.7487
#   Sensitivity  : 0.8930
#   Specificity  : 0.3615
#   AUC-ROC      : 0.7619
#
# --- Text Evaluation (Epoch 8) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4000
#   ROUGE-L F1   : 0.3948
# ✓ New best AUC-ROC: 0.7619
#
# Epoch 9/50
# Training loss: 8.1111
# Classification loss: 0.5043
# Generation loss: 0.8061
# Weighted gen loss: 8.060618
# Validation loss: 7.4006
# Validation metrics:
#   Accuracy     : 0.7442
#   F1-Score     : 0.7488
#   Sensitivity  : 0.8129
#   Specificity  : 0.5291
#   AUC-ROC      : 0.7674
#
# --- Text Evaluation (Epoch 9) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4158
#   ROUGE-L F1   : 0.4053
# ✓ New best AUC-ROC: 0.7674
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 10/50
# Training loss: 7.9649
# Classification loss: 0.4990
# Generation loss: 0.7915
# Weighted gen loss: 7.914984
# Validation loss: 7.2933
# Validation metrics:
#   Accuracy     : 0.7671
#   F1-Score     : 0.7675
#   Sensitivity  : 0.8449
#   Specificity  : 0.5234
#   AUC-ROC      : 0.7815
#
# --- Text Evaluation (Epoch 10) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4134
#   ROUGE-L F1   : 0.4064
# ✓ New best F1: 0.7675
# ✓ New best AUC-ROC: 0.7815
#
# Epoch 11/50
# Training loss: 7.8269
# Classification loss: 0.4914
# Generation loss: 0.7778
# Weighted gen loss: 7.777762
# Validation loss: 7.1516
# Validation metrics:
#   Accuracy     : 0.7530
#   F1-Score     : 0.7598
#   Sensitivity  : 0.8071
#   Specificity  : 0.5838
#   AUC-ROC      : 0.7853
#
# --- Text Evaluation (Epoch 11) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4128
#   ROUGE-L F1   : 0.4025
# ✓ New best AUC-ROC: 0.7853
#
# Epoch 12/50
# Training loss: 7.6959
# Classification loss: 0.4879
# Generation loss: 0.7647
# Weighted gen loss: 7.647085
# Validation loss: 7.0930
# Validation metrics:
#   Accuracy     : 0.7616
#   F1-Score     : 0.7651
#   Sensitivity  : 0.8278
#   Specificity  : 0.5542
#   AUC-ROC      : 0.7833
#
# --- Text Evaluation (Epoch 12) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4198
#   ROUGE-L F1   : 0.4122
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 13/50
# Training loss: 7.6030
# Classification loss: 0.4847
# Generation loss: 0.7555
# Weighted gen loss: 7.554579
# Validation loss: 7.0577
# Validation metrics:
#   Accuracy     : 0.7635
#   F1-Score     : 0.7636
#   Sensitivity  : 0.8438
#   Specificity  : 0.5120
#   AUC-ROC      : 0.7870
#
# --- Text Evaluation (Epoch 13) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4209
#   ROUGE-L F1   : 0.4139
# ✓ New best AUC-ROC: 0.7870
#
# Epoch 14/50
# Training loss: 7.4933
# Classification loss: 0.4829
# Generation loss: 0.7445
# Weighted gen loss: 7.445016
# Validation loss: 7.0170
# Validation metrics:
#   Accuracy     : 0.7627
#   F1-Score     : 0.7651
#   Sensitivity  : 0.8336
#   Specificity  : 0.5405
#   AUC-ROC      : 0.7892
#
# --- Text Evaluation (Epoch 14) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4181
#   ROUGE-L F1   : 0.4042
# ✓ New best AUC-ROC: 0.7892
#
# Epoch 15/50
# Training loss: 7.4125
# Classification loss: 0.4788
# Generation loss: 0.7365
# Weighted gen loss: 7.364627
# Validation loss: 6.8747
# Validation metrics:
#   Accuracy     : 0.7646
#   F1-Score     : 0.7665
#   Sensitivity  : 0.8369
#   Specificity  : 0.5382
#   AUC-ROC      : 0.7902
#
# --- Text Evaluation (Epoch 15) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4134
#   ROUGE-L F1   : 0.3998
# ✓ New best AUC-ROC: 0.7902
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 16/50
# Training loss: 7.3199
# Classification loss: 0.4778
# Generation loss: 0.7272
# Weighted gen loss: 7.272160
# Validation loss: 6.8680
# Validation metrics:
#   Accuracy     : 0.7693
#   F1-Score     : 0.7630
#   Sensitivity  : 0.8708
#   Specificity  : 0.4515
#   AUC-ROC      : 0.7958
#
# --- Text Evaluation (Epoch 16) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4146
#   ROUGE-L F1   : 0.4109
# ✓ New best AUC-ROC: 0.7958
#
# Epoch 17/50
# Training loss: 7.2296
# Classification loss: 0.4775
# Generation loss: 0.7182
# Weighted gen loss: 7.181839
# Validation loss: 6.8581
# Validation metrics:
#   Accuracy     : 0.7508
#   F1-Score     : 0.7595
#   Sensitivity  : 0.7958
#   Specificity  : 0.6100
#   AUC-ROC      : 0.7919
#
# --- Text Evaluation (Epoch 17) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4087
#   ROUGE-L F1   : 0.4069
#
# Epoch 18/50
# Training loss: 7.1631
# Classification loss: 0.4753
# Generation loss: 0.7116
# Weighted gen loss: 7.115610
# Validation loss: 6.6762
# Validation metrics:
#   Accuracy     : 0.7674
#   F1-Score     : 0.7705
#   Sensitivity  : 0.8329
#   Specificity  : 0.5621
#   AUC-ROC      : 0.8008
#
# --- Text Evaluation (Epoch 18) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4023
#   ROUGE-L F1   : 0.4034
# ✓ New best F1: 0.7705
# ✓ New best AUC-ROC: 0.8008
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 19/50
# Training loss: 7.0876
# Classification loss: 0.4746
# Generation loss: 0.7040
# Weighted gen loss: 7.040127
# Validation loss: 6.6822
# Validation metrics:
#   Accuracy     : 0.7696
#   F1-Score     : 0.7660
#   Sensitivity  : 0.8617
#   Specificity  : 0.4812
#   AUC-ROC      : 0.8003
#
# --- Text Evaluation (Epoch 19) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3996
#   ROUGE-L F1   : 0.3891
#
# Epoch 20/50
# Training loss: 7.0140
# Classification loss: 0.4703
# Generation loss: 0.6967
# Weighted gen loss: 6.967010
# Validation loss: 6.6488
# Validation metrics:
#   Accuracy     : 0.7724
#   F1-Score     : 0.7739
#   Sensitivity  : 0.8431
#   Specificity  : 0.5507
#   AUC-ROC      : 0.8071
#
# --- Text Evaluation (Epoch 20) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4018
#   ROUGE-L F1   : 0.4046
# ✓ New best accuracy: 0.7724
# ✓ New best F1: 0.7739
# ✓ New best AUC-ROC: 0.8071
#
# Epoch 21/50
# Training loss: 6.9555
# Classification loss: 0.4700
# Generation loss: 0.6908
# Weighted gen loss: 6.908485
# Validation loss: 6.5175
# Validation metrics:
#   Accuracy     : 0.7798
#   F1-Score     : 0.7782
#   Sensitivity  : 0.8613
#   Specificity  : 0.5245
#   AUC-ROC      : 0.8047
#
# --- Text Evaluation (Epoch 21) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4160
#   ROUGE-L F1   : 0.4186
#   ✓ New best ROUGE-L F1: 0.4186
# ✓ New best accuracy: 0.7798
# ✓ New best F1: 0.7782
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 22/50
# Training loss: 6.8915
# Classification loss: 0.4708
# Generation loss: 0.6844
# Weighted gen loss: 6.844401
# Validation loss: 6.5316
# Validation metrics:
#   Accuracy     : 0.7864
#   F1-Score     : 0.7796
#   Sensitivity  : 0.8853
#   Specificity  : 0.4766
#   AUC-ROC      : 0.8021
#
# --- Text Evaluation (Epoch 22) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4029
#   ROUGE-L F1   : 0.4021
# ✓ New best accuracy: 0.7864
# ✓ New best F1: 0.7796
#
# Epoch 23/50
# Training loss: 6.8348
# Classification loss: 0.4682
# Generation loss: 0.6788
# Weighted gen loss: 6.787956
# Validation loss: 6.4428
# Validation metrics:
#   Accuracy     : 0.7806
#   F1-Score     : 0.7755
#   Sensitivity  : 0.8751
#   Specificity  : 0.4846
#   AUC-ROC      : 0.8012
#
# --- Text Evaluation (Epoch 23) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4044
#   ROUGE-L F1   : 0.4081
#
# Epoch 24/50
# Training loss: 6.7842
# Classification loss: 0.4645
# Generation loss: 0.6738
# Weighted gen loss: 6.737702
# Validation loss: 6.4599
# Validation metrics:
#   Accuracy     : 0.7657
#   F1-Score     : 0.7694
#   Sensitivity  : 0.8296
#   Specificity  : 0.5656
#   AUC-ROC      : 0.8006
#
# --- Text Evaluation (Epoch 24) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4182
#   ROUGE-L F1   : 0.4130
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 25/50
# Training loss: 6.7329
# Classification loss: 0.4652
# Generation loss: 0.6686
# Weighted gen loss: 6.686347
# Validation loss: 6.4026
# Validation metrics:
#   Accuracy     : 0.7809
#   F1-Score     : 0.7759
#   Sensitivity  : 0.8748
#   Specificity  : 0.4869
#   AUC-ROC      : 0.8039
#
# --- Text Evaluation (Epoch 25) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4128
#   ROUGE-L F1   : 0.4087
#
# Epoch 26/50
# Training loss: 6.6885
# Classification loss: 0.4636
# Generation loss: 0.6642
# Weighted gen loss: 6.642116
# Validation loss: 6.3263
# Validation metrics:
#   Accuracy     : 0.7608
#   F1-Score     : 0.7679
#   Sensitivity  : 0.8092
#   Specificity  : 0.6089
#   AUC-ROC      : 0.8038
#
# --- Text Evaluation (Epoch 26) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4105
#   ROUGE-L F1   : 0.4039
#
# Epoch 27/50
# Training loss: 6.6509
# Classification loss: 0.4646
# Generation loss: 0.6604
# Weighted gen loss: 6.604470
# Validation loss: 6.3185
# Validation metrics:
#   Accuracy     : 0.7712
#   F1-Score     : 0.7716
#   Sensitivity  : 0.8475
#   Specificity  : 0.5325
#   AUC-ROC      : 0.8001
#
# --- Text Evaluation (Epoch 27) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4166
#   ROUGE-L F1   : 0.4111
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 28/50
# Training loss: 6.5907
# Classification loss: 0.4629
# Generation loss: 0.6544
# Weighted gen loss: 6.544366
# Validation loss: 6.2644
# Validation metrics:
#   Accuracy     : 0.7790
#   F1-Score     : 0.7745
#   Sensitivity  : 0.8715
#   Specificity  : 0.4892
#   AUC-ROC      : 0.8028
#
# --- Text Evaluation (Epoch 28) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4183
#   ROUGE-L F1   : 0.4128
#
# Epoch 29/50
# Training loss: 6.5552
# Classification loss: 0.4556
# Generation loss: 0.6510
# Weighted gen loss: 6.509617
# Validation loss: 6.2458
# Validation metrics:
#   Accuracy     : 0.7770
#   F1-Score     : 0.7757
#   Sensitivity  : 0.8584
#   Specificity  : 0.5222
#   AUC-ROC      : 0.8027
#
# --- Text Evaluation (Epoch 29) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4236
#   ✓ New best METEOR: 0.4236
#   ROUGE-L F1   : 0.4221
#   ✓ New best ROUGE-L F1: 0.4221
#
# Epoch 30/50
# Training loss: 6.5107
# Classification loss: 0.4611
# Generation loss: 0.6465
# Weighted gen loss: 6.464571
# Validation loss: 6.2201
# Validation metrics:
#   Accuracy     : 0.7895
#   F1-Score     : 0.7797
#   Sensitivity  : 0.8973
#   Specificity  : 0.4515
#   AUC-ROC      : 0.8085
#
# --- Text Evaluation (Epoch 30) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4138
#   ROUGE-L F1   : 0.4157
# ✓ New best accuracy: 0.7895
# ✓ New best F1: 0.7797
# ✓ New best AUC-ROC: 0.8085
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 31/50
# Training loss: 6.4645
# Classification loss: 0.4598
# Generation loss: 0.6419
# Weighted gen loss: 6.418503
# Validation loss: 6.1940
# Validation metrics:
#   Accuracy     : 0.7768
#   F1-Score     : 0.7745
#   Sensitivity  : 0.8617
#   Specificity  : 0.5108
#   AUC-ROC      : 0.8031
#
# --- Text Evaluation (Epoch 31) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4134
#   ROUGE-L F1   : 0.4105
#
# Epoch 32/50
# Training loss: 6.4310
# Classification loss: 0.4581
# Generation loss: 0.6385
# Weighted gen loss: 6.385167
# Validation loss: 6.1734
# Validation metrics:
#   Accuracy     : 0.7809
#   F1-Score     : 0.7790
#   Sensitivity  : 0.8631
#   Specificity  : 0.5234
#   AUC-ROC      : 0.8077
#
# --- Text Evaluation (Epoch 32) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4172
#   ROUGE-L F1   : 0.4196
#
# Epoch 33/50
# Training loss: 6.4000
# Classification loss: 0.4604
# Generation loss: 0.6354
# Weighted gen loss: 6.353964
# Validation loss: 6.1754
# Validation metrics:
#   Accuracy     : 0.7740
#   F1-Score     : 0.7692
#   Sensitivity  : 0.8689
#   Specificity  : 0.4766
#   AUC-ROC      : 0.8008
#
# --- Text Evaluation (Epoch 33) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4144
#   ROUGE-L F1   : 0.4143
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 34/50
# Training loss: 6.3682
# Classification loss: 0.4583
# Generation loss: 0.6322
# Weighted gen loss: 6.322347
# Validation loss: 6.1706
# Validation metrics:
#   Accuracy     : 0.7743
#   F1-Score     : 0.7760
#   Sensitivity  : 0.8438
#   Specificity  : 0.5564
#   AUC-ROC      : 0.8094
#
# --- Text Evaluation (Epoch 34) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4224
#   ROUGE-L F1   : 0.4159
# ✓ New best AUC-ROC: 0.8094
#
# Epoch 35/50
# Training loss: 6.3376
# Classification loss: 0.4549
# Generation loss: 0.6292
# Weighted gen loss: 6.292110
# Validation loss: 6.1001
# Validation metrics:
#   Accuracy     : 0.7712
#   F1-Score     : 0.7706
#   Sensitivity  : 0.8518
#   Specificity  : 0.5188
#   AUC-ROC      : 0.8053
#
# --- Text Evaluation (Epoch 35) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4104
#   ROUGE-L F1   : 0.4069
#
# Epoch 36/50
# Training loss: 6.3041
# Classification loss: 0.4595
# Generation loss: 0.6258
# Weighted gen loss: 6.258178
# Validation loss: 6.0696
# Validation metrics:
#   Accuracy     : 0.7801
#   F1-Score     : 0.7794
#   Sensitivity  : 0.8577
#   Specificity  : 0.5371
#   AUC-ROC      : 0.8083
#
# --- Text Evaluation (Epoch 36) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4216
#   ROUGE-L F1   : 0.4201
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 37/50
# Training loss: 6.2692
# Classification loss: 0.4543
# Generation loss: 0.6224
# Weighted gen loss: 6.223774
# Validation loss: 6.0392
# Validation metrics:
#   Accuracy     : 0.7748
#   F1-Score     : 0.7784
#   Sensitivity  : 0.8355
#   Specificity  : 0.5849
#   AUC-ROC      : 0.8112
#
# --- Text Evaluation (Epoch 37) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4127
#   ROUGE-L F1   : 0.4135
# ✓ New best AUC-ROC: 0.8112
#
# Epoch 38/50
# Training loss: 6.2378
# Classification loss: 0.4509
# Generation loss: 0.6193
# Weighted gen loss: 6.192670
# Validation loss: 6.0715
# Validation metrics:
#   Accuracy     : 0.7682
#   F1-Score     : 0.7746
#   Sensitivity  : 0.8169
#   Specificity  : 0.6157
#   AUC-ROC      : 0.8148
#
# --- Text Evaluation (Epoch 38) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4211
#   ROUGE-L F1   : 0.4178
# ✓ New best AUC-ROC: 0.8148
#
# Epoch 39/50
# Training loss: 6.2188
# Classification loss: 0.4509
# Generation loss: 0.6174
# Weighted gen loss: 6.173690
# Validation loss: 6.0444
# Validation metrics:
#   Accuracy     : 0.7737
#   F1-Score     : 0.7748
#   Sensitivity  : 0.8464
#   Specificity  : 0.5462
#   AUC-ROC      : 0.8106
#
# --- Text Evaluation (Epoch 39) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4099
#   ROUGE-L F1   : 0.4104
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 40/50
# Training loss: 6.1909
# Classification loss: 0.4518
# Generation loss: 0.6146
# Weighted gen loss: 6.145673
# Validation loss: 6.0057
# Validation metrics:
#   Accuracy     : 0.7815
#   F1-Score     : 0.7801
#   Sensitivity  : 0.8613
#   Specificity  : 0.5314
#   AUC-ROC      : 0.8131
#
# --- Text Evaluation (Epoch 40) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4136
#   ROUGE-L F1   : 0.4153
# ✓ New best F1: 0.7801
#
# Epoch 41/50
# Training loss: 6.1755
# Classification loss: 0.4536
# Generation loss: 0.6130
# Weighted gen loss: 6.130185
# Validation loss: 6.0320
# Validation metrics:
#   Accuracy     : 0.7823
#   F1-Score     : 0.7806
#   Sensitivity  : 0.8635
#   Specificity  : 0.5279
#   AUC-ROC      : 0.8147
#
# --- Text Evaluation (Epoch 41) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4200
#   ROUGE-L F1   : 0.4174
# ✓ New best F1: 0.7806
#
# Epoch 42/50
# Training loss: 6.1342
# Classification loss: 0.4507
# Generation loss: 0.6089
# Weighted gen loss: 6.089134
# Validation loss: 5.9839
# Validation metrics:
#   Accuracy     : 0.7784
#   F1-Score     : 0.7747
#   Sensitivity  : 0.8686
#   Specificity  : 0.4960
#   AUC-ROC      : 0.8113
#
# --- Text Evaluation (Epoch 42) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4119
#   ROUGE-L F1   : 0.4149
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 43/50
# Training loss: 6.1100
# Classification loss: 0.4505
# Generation loss: 0.6065
# Weighted gen loss: 6.064938
# Validation loss: 6.0008
# Validation metrics:
#   Accuracy     : 0.7837
#   F1-Score     : 0.7794
#   Sensitivity  : 0.8744
#   Specificity  : 0.4994
#   AUC-ROC      : 0.8120
#
# --- Text Evaluation (Epoch 43) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4198
#   ROUGE-L F1   : 0.4148
#
# Epoch 44/50
# Training loss: 6.0826
# Classification loss: 0.4486
# Generation loss: 0.6038
# Weighted gen loss: 6.037719
# Validation loss: 5.9769
# Validation metrics:
#   Accuracy     : 0.7850
#   F1-Score     : 0.7820
#   Sensitivity  : 0.8708
#   Specificity  : 0.5165
#   AUC-ROC      : 0.8117
#
# --- Text Evaluation (Epoch 44) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4138
#   ROUGE-L F1   : 0.4132
# ✓ New best F1: 0.7820
#
# Epoch 45/50
# Training loss: 6.0641
# Classification loss: 0.4516
# Generation loss: 0.6019
# Weighted gen loss: 6.018901
# Validation loss: 6.0108
# Validation metrics:
#   Accuracy     : 0.7798
#   F1-Score     : 0.7845
#   Sensitivity  : 0.8325
#   Specificity  : 0.6146
#   AUC-ROC      : 0.8178
#
# --- Text Evaluation (Epoch 45) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4177
#   ROUGE-L F1   : 0.4153
# ✓ New best F1: 0.7845
# ✓ New best AUC-ROC: 0.8178
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 46/50
# Training loss: 6.0421
# Classification loss: 0.4466
# Generation loss: 0.5997
# Weighted gen loss: 5.997418
# Validation loss: 5.9362
# Validation metrics:
#   Accuracy     : 0.7809
#   F1-Score     : 0.7814
#   Sensitivity  : 0.8533
#   Specificity  : 0.5542
#   AUC-ROC      : 0.8154
#
# --- Text Evaluation (Epoch 46) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4127
#   ROUGE-L F1   : 0.4142
#
# Epoch 47/50
# Training loss: 6.0170
# Classification loss: 0.4484
# Generation loss: 0.5972
# Weighted gen loss: 5.972158
# Validation loss: 5.9225
# Validation metrics:
#   Accuracy     : 0.7718
#   F1-Score     : 0.7773
#   Sensitivity  : 0.8238
#   Specificity  : 0.6089
#   AUC-ROC      : 0.8110
#
# --- Text Evaluation (Epoch 47) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4211
#   ROUGE-L F1   : 0.4228
#   ✓ New best ROUGE-L F1: 0.4228
#
# Epoch 48/50
# Training loss: 5.9890
# Classification loss: 0.4493
# Generation loss: 0.5944
# Weighted gen loss: 5.944035
# Validation loss: 5.9450
# Validation metrics:
#   Accuracy     : 0.7817
#   F1-Score     : 0.7734
#   Sensitivity  : 0.8868
#   Specificity  : 0.4527
#   AUC-ROC      : 0.8124
#
# --- Text Evaluation (Epoch 48) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4196
#   ROUGE-L F1   : 0.4154
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 49/50
# Training loss: 5.9709
# Classification loss: 0.4491
# Generation loss: 0.5926
# Weighted gen loss: 5.926030
# Validation loss: 5.9196
# Validation metrics:
#   Accuracy     : 0.7817
#   F1-Score     : 0.7776
#   Sensitivity  : 0.8722
#   Specificity  : 0.4983
#   AUC-ROC      : 0.8104
#
# --- Text Evaluation (Epoch 49) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4166
#   ROUGE-L F1   : 0.4140
#
# Epoch 50/50
# Training loss: 5.9473
# Classification loss: 0.4452
# Generation loss: 0.5903
# Weighted gen loss: 5.902752
# Validation loss: 5.9284
# Validation metrics:
#   Accuracy     : 0.7809
#   F1-Score     : 0.7808
#   Sensitivity  : 0.8558
#   Specificity  : 0.5462
#   AUC-ROC      : 0.8159
#
# --- Text Evaluation (Epoch 50) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4217
#   ROUGE-L F1   : 0.4155
# ============================================================
# TRAINING SUMMARY
# ============================================================
# Best Accuracy: 0.7895
# Best F1-Score: 0.7845
# Best AUC-ROC: 0.8178
# Best METEOR: 0.4236
# Best ROUGE-L: 0.4228
# ============================================================

# %% [markdown]
# ### Test Model and Display Text Generation Sample

# %%
test_loss_sampled, test_metrics_sampled = print_test_evaluation(model, test_loader, device, tokenizer, test_df)
# Out:
# Training completed!
# Best results from validation:
#
# ==================================================
# FINAL TEST SET EVALUATION
# ==================================================
#
# 1. Full Classification Performance:
# Test loss: 5.8818
# Classification metrics (all 3625 samples):
#   Accuracy     : 0.7942
#   F1-Score     : 0.7932
#   Sensitivity  : 0.8687
#   Specificity  : 0.5605
#   AUC-ROC      : 0.8303
#
# 2. Sampled Text Generation Performance:
# Evaluating text generation on FULL dataset (3625 samples)
# Computing text metrics on 3625 samples...
# Text generation metrics (3625 samples):
#   ROUGE-L F1   : 0.4160
#   METEOR       : 0.4228
#
# Sample efficiency: 3625/3625 samples used for text metrics

# %%
display_generated_texts(test_metrics_sampled['generated_texts'], test_metrics_sampled['reference_texts'], num_samples=20)
# Out:
# Displaying 20 randomly selected text generation samples:
#
# Sample 2620
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature values are not exceeded, and there are no signs of locally increased metabolism in the breast tissue.
# ----------------------------------------
#
# Sample 457
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# Reference : The measured temperature is asymmetrical, with asymmetry this time exceeding the recommended values. We recommend that the lady undergo an early breast scan check in 6-7 months (08-09.2019) and regularly perform self-examinations. She will also have physiotherapy for the cervical spine.
# ----------------------------------------
#
# Sample 103
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examinations once a month, regular control clinical examinations, and a repeat breast scan measurement in one year.
# ----------------------------------------
#
# Sample 3038
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The values of the measured temperature are at the upper limit of the recommended values.
# ----------------------------------------
#
# Sample 1127
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The temperature level is completely higher than the recommended value, surface asymmetry has been exceeded, but its distribution currently does not indicate signs of locally increased metabolism in the breast tissue. A follow-up is recommended in one year (02.2016). During this period, regular self-examination and preventive
# ----------------------------------------
#
# Sample 1004
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend the next check-up in 1 year (03. 2015). During this period, we advise regular self-examination. In case of noticeable, visible changes, discharge, or prolonged pain, please schedule an earlier check
# Reference : Values of the measured temperature are currently exceeded.
# ----------------------------------------
#
# Sample 915
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# ----------------------------------------
#
# Sample 572
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend the next check-up in 1 year (03. 2015). During this period, we advise regular self-examination. In case of noticeable, visible changes, discharge, or prolonged pain, please schedule an earlier check
# Reference : The measured temperature is asymmetrically distributed, the asymmetry is exceeded, but its distribution does not indicate signs of locally higher metabolism in breast tissue. We recommend monitoring the temperature for 1 year (06.2019). During this period, we advise regular self-examination; as an additional preventive
# ----------------------------------------
#
# Sample 3017
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The temperature is asymmetrically distributed and higher than the recommended temperature level. The right breast is completely warmer compared to the left. I advise an immediate clinical examination by a specialist oncologist and expanded diagnostics. In the case of continued monitoring of the disease, I recommend regular follow-up measurements
# ----------------------------------------
#
# Sample 420
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally elevated metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# ----------------------------------------
#
# Sample 2772
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally elevated metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I recommend regular self-examination and a repeat breast scan measurement in two years. In case of noticeable visible changes or prolonged pain, I advise a clinical examination by a specialist and an early measurement.
# ----------------------------------------
#
# Sample 3034
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend the next check-up in 1 year (03. 2015). During this period, we advise regular self-examinations. In case of noticeable, visible changes, discharge, or prolonged pain, please schedule an earlier
# Reference : The measured temperature is asymmetrical, the level slightly higher, the asymmetry exceeded, but its distribution currently does not indicate signs of locally higher metabolism in breast tissue. We advise regular self-examination and comparative control in 6-8 months (10th-12th 2017), if possible on the
# ----------------------------------------
#
# Sample 2234
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# Reference : The measured temperature values are at the upper limit of the recommended range; the left breast is still entirely warmer (similar to the measurement from 2007), and currently, there are no significant signs of locally elevated metabolism in the breast tissue. We recommend the next breastscan measurement no later than 1 year from now (06.
# ----------------------------------------
#
# Sample 357
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# ----------------------------------------
#
# Sample 2419
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The temperature distribution is symmetrical. No signs of local hyperthermia in the breasts are detected. I recommend regular self-examination once a month and a systematic check-up in one year.
# ----------------------------------------
#
# Sample 1729
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrically distributed, but its distribution currently does not indicate signs of locally elevated metabolism in the breast tissue. We recommend a follow-up breast scan in 1 year (August 2015). During this period, the lady will perform self-examinations and undergo a ma
# ----------------------------------------
#
# Sample 131
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrically distributed. The maximum temperature asymmetry was measured in the external superior quadrant (from +1.1 to +1.2 degrees). I recommend repeating the breast scan measurement in 6 months. In case of significant changes or prolonged pain, please contact us sooner as agreed.
# ----------------------------------------
#
# Sample 123
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend the next check-up in 1 year (03. 2015). During this period, we advise regular self-examinations. In case of noticeable, visible changes, discharge, or prolonged pain, please schedule an earlier
# Reference : The measured temperature in the breast tissue is asymmetrically distributed, with values on the surface exceeding the recommended limit; however, its distribution does not currently indicate signs of locally increased metabolism. We recommend a comparative follow-up in 6-8 months (08-10.2011). During this period, we
# ----------------------------------------
#
# Sample 384
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend the next check-up in 1 year (03. 2015). During this period, we advise regular self-examinations. In case of noticeable, visible changes, discharge, or prolonged pain, please schedule an earlier
# Reference : The 2nd level and the distribution of measured temperatures do not indicate signs of locally elevated metabolism in the breast tissue. A follow-up is recommended in 1 year (06. 2019). During this period, we advise regular self-examination. In the case of noticeable, visible changes, discharge, or prolonged
# ----------------------------------------
#
# Sample 896
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in breast tissue. I recommend regular self-examination and a repeat breast scan measurement in one year. In the case of palpable, visible changes, discharge, or prolonged pain, I advise a clinical examination by a specialist doctor and
# ----------------------------------------

# %% [markdown]
# ## Cross Attention and Minimal Text

# %% [markdown]
# ### Initialise Model

# %%
tokenizer, train_loader, val_loader, test_loader, model, optimizer, device = create_experiment_pipeline(
    train_df, val_df, test_df,
    projection_mode='attention',         
    projection_type='attention',         
    use_minimal_text=True,          
    batch_size=32,
    learning_rate=5e-5
)
# Out:
# ============================================================
# EXPERIMENT: ATTENTION projection + MINIMAL text
# Projection type: attention
# ============================================================
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Using device: cuda
# Model configuration:
#   Projection mode: attention
#   Projection type: attention
#   Minimal text: True
#   Feature projection: Yes

# %% [markdown]
# ### Train Model

# %%
best_accuracy, best_f1, best_auc, best_meteor, best_rougeL = train_and_validate_model_with_meteor_rouge(
    model, train_loader, val_loader, optimizer, device, tokenizer, num_epochs=50, meteor_every=1
)
# Out:
# Epoch 1/50
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Training loss: 19.1273
# Classification loss: 0.7388
# Generation loss: 1.9053
# Weighted gen loss: 19.053403
# Validation loss: 10.7515
# Validation metrics:
#   Accuracy     : 0.7461
#   F1-Score     : 0.7087
#   Sensitivity  : 0.9195
#   Specificity  : 0.2030
#   AUC-ROC      : 0.6818
#
# --- Text Evaluation (Epoch 1) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4036
#   ✓ New best METEOR: 0.4036
#   ROUGE-L F1   : 0.4184
#   ✓ New best ROUGE-L F1: 0.4184
# ✓ New best accuracy: 0.7461
# ✓ New best F1: 0.7087
# ✓ New best AUC-ROC: 0.6818
#
# Epoch 2/50
# Training loss: 11.5802
# Classification loss: 0.5516
# Generation loss: 1.1525
# Weighted gen loss: 11.525022
# Validation loss: 9.4365
# Validation metrics:
#   Accuracy     : 0.7522
#   F1-Score     : 0.7240
#   Sensitivity  : 0.9094
#   Specificity  : 0.2600
#   AUC-ROC      : 0.7072
#
# --- Text Evaluation (Epoch 2) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4236
#   ✓ New best METEOR: 0.4236
#   ROUGE-L F1   : 0.4157
# ✓ New best accuracy: 0.7522
# ✓ New best F1: 0.7240
# ✓ New best AUC-ROC: 0.7072
#
# Epoch 3/50
# Training loss: 10.4461
# Classification loss: 0.5352
# Generation loss: 1.0393
# Weighted gen loss: 10.392533
# Validation loss: 8.7887
# Validation metrics:
#   Accuracy     : 0.7572
#   F1-Score     : 0.7203
#   Sensitivity  : 0.9286
#   Specificity  : 0.2201
#   AUC-ROC      : 0.7116
#
# --- Text Evaluation (Epoch 3) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3843
#   ROUGE-L F1   : 0.3793
# ✓ New best accuracy: 0.7572
# ✓ New best AUC-ROC: 0.7116
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 4/50
# Training loss: 9.8039
# Classification loss: 0.5273
# Generation loss: 0.9751
# Weighted gen loss: 9.751138
# Validation loss: 8.4433
# Validation metrics:
#   Accuracy     : 0.7561
#   F1-Score     : 0.7408
#   Sensitivity  : 0.8853
#   Specificity  : 0.3512
#   AUC-ROC      : 0.7311
#
# --- Text Evaluation (Epoch 4) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4223
#   ROUGE-L F1   : 0.4142
# ✓ New best F1: 0.7408
# ✓ New best AUC-ROC: 0.7311
#
# Epoch 5/50
# Training loss: 9.3950
# Classification loss: 0.5162
# Generation loss: 0.9343
# Weighted gen loss: 9.343406
# Validation loss: 8.1143
# Validation metrics:
#   Accuracy     : 0.7530
#   F1-Score     : 0.7441
#   Sensitivity  : 0.8664
#   Specificity  : 0.3979
#   AUC-ROC      : 0.7420
#
# --- Text Evaluation (Epoch 5) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3772
#   ROUGE-L F1   : 0.3727
# ✓ New best F1: 0.7441
# ✓ New best AUC-ROC: 0.7420
#
# Epoch 6/50
# Training loss: 9.0552
# Classification loss: 0.5136
# Generation loss: 0.9004
# Weighted gen loss: 9.003877
# Validation loss: 7.9516
# Validation metrics:
#   Accuracy     : 0.7558
#   F1-Score     : 0.7488
#   Sensitivity  : 0.8628
#   Specificity  : 0.4208
#   AUC-ROC      : 0.7522
#
# --- Text Evaluation (Epoch 6) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4236
#   ROUGE-L F1   : 0.4157
# ✓ New best F1: 0.7488
# ✓ New best AUC-ROC: 0.7522
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 7/50
# Training loss: 8.8041
# Classification loss: 0.5037
# Generation loss: 0.8754
# Weighted gen loss: 8.753698
# Validation loss: 7.8154
# Validation metrics:
#   Accuracy     : 0.7541
#   F1-Score     : 0.7463
#   Sensitivity  : 0.8639
#   Specificity  : 0.4105
#   AUC-ROC      : 0.7595
#
# --- Text Evaluation (Epoch 7) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4236
#   ROUGE-L F1   : 0.4157
# ✓ New best AUC-ROC: 0.7595
#
# Epoch 8/50
# Training loss: 8.5854
# Classification loss: 0.5035
# Generation loss: 0.8535
# Weighted gen loss: 8.535057
# Validation loss: 7.6304
# Validation metrics:
#   Accuracy     : 0.7577
#   F1-Score     : 0.7443
#   Sensitivity  : 0.8821
#   Specificity  : 0.3683
#   AUC-ROC      : 0.7638
#
# --- Text Evaluation (Epoch 8) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4234
#   ROUGE-L F1   : 0.4160
# ✓ New best accuracy: 0.7577
# ✓ New best AUC-ROC: 0.7638
#
# Epoch 9/50
# Training loss: 8.3913
# Classification loss: 0.4976
# Generation loss: 0.8342
# Weighted gen loss: 8.341582
# Validation loss: 7.5763
# Validation metrics:
#   Accuracy     : 0.7514
#   F1-Score     : 0.7516
#   Sensitivity  : 0.8351
#   Specificity  : 0.4892
#   AUC-ROC      : 0.7713
#
# --- Text Evaluation (Epoch 9) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3844
#   ROUGE-L F1   : 0.3797
# ✓ New best F1: 0.7516
# ✓ New best AUC-ROC: 0.7713
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 10/50
# Training loss: 8.2409
# Classification loss: 0.4918
# Generation loss: 0.8192
# Weighted gen loss: 8.191683
# Validation loss: 7.4515
# Validation metrics:
#   Accuracy     : 0.7555
#   F1-Score     : 0.7521
#   Sensitivity  : 0.8511
#   Specificity  : 0.4561
#   AUC-ROC      : 0.7743
#
# --- Text Evaluation (Epoch 10) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4234
#   ROUGE-L F1   : 0.4160
# ✓ New best F1: 0.7521
# ✓ New best AUC-ROC: 0.7743
#
# Epoch 11/50
# Training loss: 8.1029
# Classification loss: 0.4881
# Generation loss: 0.8054
# Weighted gen loss: 8.054089
# Validation loss: 7.3126
# Validation metrics:
#   Accuracy     : 0.7610
#   F1-Score     : 0.7567
#   Sensitivity  : 0.8580
#   Specificity  : 0.4572
#   AUC-ROC      : 0.7787
#
# --- Text Evaluation (Epoch 11) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3844
#   ROUGE-L F1   : 0.3797
# ✓ New best accuracy: 0.7610
# ✓ New best F1: 0.7567
# ✓ New best AUC-ROC: 0.7787
#
# Epoch 12/50
# Training loss: 7.9701
# Classification loss: 0.4877
# Generation loss: 0.7921
# Weighted gen loss: 7.921368
# Validation loss: 7.2980
# Validation metrics:
#   Accuracy     : 0.7632
#   F1-Score     : 0.7615
#   Sensitivity  : 0.8504
#   Specificity  : 0.4903
#   AUC-ROC      : 0.7809
#
# --- Text Evaluation (Epoch 12) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7632
# ✓ New best F1: 0.7615
# ✓ New best AUC-ROC: 0.7809
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 13/50
# Training loss: 7.8578
# Classification loss: 0.4845
# Generation loss: 0.7809
# Weighted gen loss: 7.809349
# Validation loss: 7.2613
# Validation metrics:
#   Accuracy     : 0.7646
#   F1-Score     : 0.7625
#   Sensitivity  : 0.8529
#   Specificity  : 0.4880
#   AUC-ROC      : 0.7853
#
# --- Text Evaluation (Epoch 13) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3844
#   ROUGE-L F1   : 0.3797
# ✓ New best accuracy: 0.7646
# ✓ New best F1: 0.7625
# ✓ New best AUC-ROC: 0.7853
#
# Epoch 14/50
# Training loss: 7.7514
# Classification loss: 0.4836
# Generation loss: 0.7703
# Weighted gen loss: 7.703026
# Validation loss: 7.1372
# Validation metrics:
#   Accuracy     : 0.7655
#   F1-Score     : 0.7571
#   Sensitivity  : 0.8740
#   Specificity  : 0.4253
#   AUC-ROC      : 0.7819
#
# --- Text Evaluation (Epoch 14) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7655
#
# Epoch 15/50
# Training loss: 7.6705
# Classification loss: 0.4788
# Generation loss: 0.7623
# Weighted gen loss: 7.622606
# Validation loss: 7.0732
# Validation metrics:
#   Accuracy     : 0.7635
#   F1-Score     : 0.7628
#   Sensitivity  : 0.8467
#   Specificity  : 0.5029
#   AUC-ROC      : 0.7838
#
# --- Text Evaluation (Epoch 15) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3843
#   ROUGE-L F1   : 0.3793
# ✓ New best F1: 0.7628
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 16/50
# Training loss: 7.5732
# Classification loss: 0.4796
# Generation loss: 0.7525
# Weighted gen loss: 7.525223
# Validation loss: 7.0124
# Validation metrics:
#   Accuracy     : 0.7724
#   F1-Score     : 0.7631
#   Sensitivity  : 0.8821
#   Specificity  : 0.4287
#   AUC-ROC      : 0.7936
#
# --- Text Evaluation (Epoch 16) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7724
# ✓ New best F1: 0.7631
# ✓ New best AUC-ROC: 0.7936
#
# Epoch 17/50
# Training loss: 7.4727
# Classification loss: 0.4730
# Generation loss: 0.7425
# Weighted gen loss: 7.425389
# Validation loss: 6.9620
# Validation metrics:
#   Accuracy     : 0.7506
#   F1-Score     : 0.7548
#   Sensitivity  : 0.8180
#   Specificity  : 0.5393
#   AUC-ROC      : 0.7900
#
# --- Text Evaluation (Epoch 17) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 18/50
# Training loss: 7.4125
# Classification loss: 0.4756
# Generation loss: 0.7365
# Weighted gen loss: 7.364973
# Validation loss: 6.9211
# Validation metrics:
#   Accuracy     : 0.7597
#   F1-Score     : 0.7645
#   Sensitivity  : 0.8205
#   Specificity  : 0.5690
#   AUC-ROC      : 0.7926
#
# --- Text Evaluation (Epoch 18) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4236
#   ROUGE-L F1   : 0.4157
# ✓ New best F1: 0.7645
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 19/50
# Training loss: 7.3316
# Classification loss: 0.4738
# Generation loss: 0.7284
# Weighted gen loss: 7.284251
# Validation loss: 6.8670
# Validation metrics:
#   Accuracy     : 0.7768
#   F1-Score     : 0.7694
#   Sensitivity  : 0.8799
#   Specificity  : 0.4538
#   AUC-ROC      : 0.7945
#
# --- Text Evaluation (Epoch 19) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7768
# ✓ New best F1: 0.7694
# ✓ New best AUC-ROC: 0.7945
#
# Epoch 20/50
# Training loss: 7.2481
# Classification loss: 0.4697
# Generation loss: 0.7201
# Weighted gen loss: 7.201109
# Validation loss: 6.7923
# Validation metrics:
#   Accuracy     : 0.7768
#   F1-Score     : 0.7761
#   Sensitivity  : 0.8555
#   Specificity  : 0.5302
#   AUC-ROC      : 0.7998
#
# --- Text Evaluation (Epoch 20) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best F1: 0.7761
# ✓ New best AUC-ROC: 0.7998
#
# Epoch 21/50
# Training loss: 7.1905
# Classification loss: 0.4696
# Generation loss: 0.7143
# Weighted gen loss: 7.143493
# Validation loss: 6.7049
# Validation metrics:
#   Accuracy     : 0.7646
#   F1-Score     : 0.7649
#   Sensitivity  : 0.8435
#   Specificity  : 0.5177
#   AUC-ROC      : 0.7984
#
# --- Text Evaluation (Epoch 21) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4234
#   ROUGE-L F1   : 0.4160
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 22/50
# Training loss: 7.1191
# Classification loss: 0.4702
# Generation loss: 0.7072
# Weighted gen loss: 7.072073
# Validation loss: 6.7844
# Validation metrics:
#   Accuracy     : 0.7649
#   F1-Score     : 0.7650
#   Sensitivity  : 0.8446
#   Specificity  : 0.5154
#   AUC-ROC      : 0.7955
#
# --- Text Evaluation (Epoch 22) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4234
#   ROUGE-L F1   : 0.4160
#
# Epoch 23/50
# Training loss: 7.0636
# Classification loss: 0.4674
# Generation loss: 0.7017
# Weighted gen loss: 7.016837
# Validation loss: 6.5749
# Validation metrics:
#   Accuracy     : 0.7643
#   F1-Score     : 0.7670
#   Sensitivity  : 0.8333
#   Specificity  : 0.5485
#   AUC-ROC      : 0.8019
#
# --- Text Evaluation (Epoch 23) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best AUC-ROC: 0.8019
#
# Epoch 24/50
# Training loss: 7.0161
# Classification loss: 0.4646
# Generation loss: 0.6970
# Weighted gen loss: 6.969605
# Validation loss: 6.6111
# Validation metrics:
#   Accuracy     : 0.7671
#   F1-Score     : 0.7709
#   Sensitivity  : 0.8296
#   Specificity  : 0.5713
#   AUC-ROC      : 0.7989
#
# --- Text Evaluation (Epoch 24) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 25/50
# Training loss: 6.9578
# Classification loss: 0.4650
# Generation loss: 0.6911
# Weighted gen loss: 6.911267
# Validation loss: 6.5271
# Validation metrics:
#   Accuracy     : 0.7798
#   F1-Score     : 0.7697
#   Sensitivity  : 0.8904
#   Specificity  : 0.4333
#   AUC-ROC      : 0.8052
#
# --- Text Evaluation (Epoch 25) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7798
# ✓ New best AUC-ROC: 0.8052
#
# Epoch 26/50
# Training loss: 6.9058
# Classification loss: 0.4598
# Generation loss: 0.6860
# Weighted gen loss: 6.859864
# Validation loss: 6.4570
# Validation metrics:
#   Accuracy     : 0.7450
#   F1-Score     : 0.7566
#   Sensitivity  : 0.7754
#   Specificity  : 0.6499
#   AUC-ROC      : 0.8005
#
# --- Text Evaluation (Epoch 26) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3844
#   ROUGE-L F1   : 0.3797
#
# Epoch 27/50
# Training loss: 6.8537
# Classification loss: 0.4635
# Generation loss: 0.6807
# Weighted gen loss: 6.807346
# Validation loss: 6.4533
# Validation metrics:
#   Accuracy     : 0.7632
#   F1-Score     : 0.7669
#   Sensitivity  : 0.8282
#   Specificity  : 0.5599
#   AUC-ROC      : 0.8027
#
# --- Text Evaluation (Epoch 27) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4234
#   ROUGE-L F1   : 0.4160
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 28/50
# Training loss: 6.8043
# Classification loss: 0.4610
# Generation loss: 0.6758
# Weighted gen loss: 6.758188
# Validation loss: 6.4168
# Validation metrics:
#   Accuracy     : 0.7765
#   F1-Score     : 0.7790
#   Sensitivity  : 0.8413
#   Specificity  : 0.5735
#   AUC-ROC      : 0.8061
#
# --- Text Evaluation (Epoch 28) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best F1: 0.7790
# ✓ New best AUC-ROC: 0.8061
#
# Epoch 29/50
# Training loss: 6.7662
# Classification loss: 0.4588
# Generation loss: 0.6720
# Weighted gen loss: 6.720338
# Validation loss: 6.3941
# Validation metrics:
#   Accuracy     : 0.7726
#   F1-Score     : 0.7750
#   Sensitivity  : 0.8398
#   Specificity  : 0.5621
#   AUC-ROC      : 0.8049
#
# --- Text Evaluation (Epoch 29) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 30/50
# Training loss: 6.7229
# Classification loss: 0.4615
# Generation loss: 0.6677
# Weighted gen loss: 6.676784
# Validation loss: 6.3089
# Validation metrics:
#   Accuracy     : 0.7842
#   F1-Score     : 0.7785
#   Sensitivity  : 0.8799
#   Specificity  : 0.4846
#   AUC-ROC      : 0.8113
#
# --- Text Evaluation (Epoch 30) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7842
# ✓ New best AUC-ROC: 0.8113
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 31/50
# Training loss: 6.6826
# Classification loss: 0.4598
# Generation loss: 0.6637
# Weighted gen loss: 6.636651
# Validation loss: 6.3013
# Validation metrics:
#   Accuracy     : 0.7773
#   F1-Score     : 0.7716
#   Sensitivity  : 0.8748
#   Specificity  : 0.4721
#   AUC-ROC      : 0.8026
#
# --- Text Evaluation (Epoch 31) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4234
#   ROUGE-L F1   : 0.4160
#
# Epoch 32/50
# Training loss: 6.6398
# Classification loss: 0.4598
# Generation loss: 0.6594
# Weighted gen loss: 6.593846
# Validation loss: 6.2888
# Validation metrics:
#   Accuracy     : 0.7815
#   F1-Score     : 0.7788
#   Sensitivity  : 0.8668
#   Specificity  : 0.5143
#   AUC-ROC      : 0.8088
#
# --- Text Evaluation (Epoch 32) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 33/50
# Training loss: 6.6105
# Classification loss: 0.4589
# Generation loss: 0.6565
# Weighted gen loss: 6.564558
# Validation loss: 6.2746
# Validation metrics:
#   Accuracy     : 0.7674
#   F1-Score     : 0.7668
#   Sensitivity  : 0.8489
#   Specificity  : 0.5120
#   AUC-ROC      : 0.8019
#
# --- Text Evaluation (Epoch 33) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 34/50
# Training loss: 6.5765
# Classification loss: 0.4586
# Generation loss: 0.6531
# Weighted gen loss: 6.530657
# Validation loss: 6.2377
# Validation metrics:
#   Accuracy     : 0.7685
#   F1-Score     : 0.7702
#   Sensitivity  : 0.8402
#   Specificity  : 0.5439
#   AUC-ROC      : 0.8031
#
# --- Text Evaluation (Epoch 34) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 35/50
# Training loss: 6.5383
# Classification loss: 0.4538
# Generation loss: 0.6493
# Weighted gen loss: 6.492947
# Validation loss: 6.2314
# Validation metrics:
#   Accuracy     : 0.7726
#   F1-Score     : 0.7758
#   Sensitivity  : 0.8362
#   Specificity  : 0.5735
#   AUC-ROC      : 0.8060
#
# --- Text Evaluation (Epoch 35) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4223
#   ROUGE-L F1   : 0.4142
#
# Epoch 36/50
# Training loss: 6.5091
# Classification loss: 0.4578
# Generation loss: 0.6463
# Weighted gen loss: 6.463338
# Validation loss: 6.1867
# Validation metrics:
#   Accuracy     : 0.7776
#   F1-Score     : 0.7783
#   Sensitivity  : 0.8504
#   Specificity  : 0.5496
#   AUC-ROC      : 0.8111
#
# --- Text Evaluation (Epoch 36) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 37/50
# Training loss: 6.4693
# Classification loss: 0.4539
# Generation loss: 0.6424
# Weighted gen loss: 6.423891
# Validation loss: 6.1659
# Validation metrics:
#   Accuracy     : 0.7776
#   F1-Score     : 0.7795
#   Sensitivity  : 0.8449
#   Specificity  : 0.5667
#   AUC-ROC      : 0.8135
#
# --- Text Evaluation (Epoch 37) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best F1: 0.7795
# ✓ New best AUC-ROC: 0.8135
#
# Epoch 38/50
# Training loss: 6.4460
# Classification loss: 0.4518
# Generation loss: 0.6401
# Weighted gen loss: 6.400857
# Validation loss: 6.1838
# Validation metrics:
#   Accuracy     : 0.7770
#   F1-Score     : 0.7787
#   Sensitivity  : 0.8456
#   Specificity  : 0.5621
#   AUC-ROC      : 0.8146
#
# --- Text Evaluation (Epoch 38) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best AUC-ROC: 0.8146
#
# Epoch 39/50
# Training loss: 6.4235
# Classification loss: 0.4523
# Generation loss: 0.6378
# Weighted gen loss: 6.378311
# Validation loss: 6.1145
# Validation metrics:
#   Accuracy     : 0.7729
#   F1-Score     : 0.7731
#   Sensitivity  : 0.8493
#   Specificity  : 0.5336
#   AUC-ROC      : 0.8090
#
# --- Text Evaluation (Epoch 39) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 40/50
# Training loss: 6.3970
# Classification loss: 0.4540
# Generation loss: 0.6352
# Weighted gen loss: 6.351615
# Validation loss: 6.1071
# Validation metrics:
#   Accuracy     : 0.7837
#   F1-Score     : 0.7768
#   Sensitivity  : 0.8835
#   Specificity  : 0.4709
#   AUC-ROC      : 0.8120
#
# --- Text Evaluation (Epoch 40) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.3647
#   ROUGE-L F1   : 0.3742
#
# Epoch 41/50
# Training loss: 6.3740
# Classification loss: 0.4546
# Generation loss: 0.6329
# Weighted gen loss: 6.328523
# Validation loss: 6.1171
# Validation metrics:
#   Accuracy     : 0.7809
#   F1-Score     : 0.7739
#   Sensitivity  : 0.8817
#   Specificity  : 0.4652
#   AUC-ROC      : 0.8109
#
# --- Text Evaluation (Epoch 41) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 42/50
# Training loss: 6.3357
# Classification loss: 0.4523
# Generation loss: 0.6290
# Weighted gen loss: 6.290447
# Validation loss: 6.1113
# Validation metrics:
#   Accuracy     : 0.7828
#   F1-Score     : 0.7787
#   Sensitivity  : 0.8733
#   Specificity  : 0.4994
#   AUC-ROC      : 0.8167
#
# --- Text Evaluation (Epoch 42) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best AUC-ROC: 0.8167
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 43/50
# Training loss: 6.3166
# Classification loss: 0.4524
# Generation loss: 0.6271
# Weighted gen loss: 6.271376
# Validation loss: 6.0669
# Validation metrics:
#   Accuracy     : 0.7906
#   F1-Score     : 0.7816
#   Sensitivity  : 0.8955
#   Specificity  : 0.4618
#   AUC-ROC      : 0.8148
#
# --- Text Evaluation (Epoch 43) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ✓ New best accuracy: 0.7906
# ✓ New best F1: 0.7816
#
# Epoch 44/50
# Training loss: 6.2893
# Classification loss: 0.4519
# Generation loss: 0.6244
# Weighted gen loss: 6.244117
# Validation loss: 6.0666
# Validation metrics:
#   Accuracy     : 0.7790
#   F1-Score     : 0.7739
#   Sensitivity  : 0.8737
#   Specificity  : 0.4823
#   AUC-ROC      : 0.8095
#
# --- Text Evaluation (Epoch 44) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 45/50
# Training loss: 6.2730
# Classification loss: 0.4486
# Generation loss: 0.6228
# Weighted gen loss: 6.228157
# Validation loss: 6.0521
# Validation metrics:
#   Accuracy     : 0.7748
#   F1-Score     : 0.7747
#   Sensitivity  : 0.8518
#   Specificity  : 0.5336
#   AUC-ROC      : 0.8160
#
# --- Text Evaluation (Epoch 45) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 46/50
# Training loss: 6.2430
# Classification loss: 0.4473
# Generation loss: 0.6198
# Weighted gen loss: 6.198242
# Validation loss: 6.0263
# Validation metrics:
#   Accuracy     : 0.7848
#   F1-Score     : 0.7798
#   Sensitivity  : 0.8777
#   Specificity  : 0.4937
#   AUC-ROC      : 0.8144
#
# --- Text Evaluation (Epoch 46) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 47/50
# Training loss: 6.2256
# Classification loss: 0.4497
# Generation loss: 0.6181
# Weighted gen loss: 6.180665
# Validation loss: 6.0195
# Validation metrics:
#   Accuracy     : 0.7710
#   F1-Score     : 0.7760
#   Sensitivity  : 0.8256
#   Specificity  : 0.5998
#   AUC-ROC      : 0.8097
#
# --- Text Evaluation (Epoch 47) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 48/50
# Training loss: 6.1942
# Classification loss: 0.4525
# Generation loss: 0.6149
# Weighted gen loss: 6.148915
# Validation loss: 6.0140
# Validation metrics:
#   Accuracy     : 0.7859
#   F1-Score     : 0.7730
#   Sensitivity  : 0.9035
#   Specificity  : 0.4173
#   AUC-ROC      : 0.8106
#
# --- Text Evaluation (Epoch 48) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# Current loss weights - CLF: 0.100, GEN: 10.000
#
# Epoch 49/50
# Training loss: 6.1729
# Classification loss: 0.4488
# Generation loss: 0.6128
# Weighted gen loss: 6.127987
# Validation loss: 6.0040
# Validation metrics:
#   Accuracy     : 0.7820
#   F1-Score     : 0.7783
#   Sensitivity  : 0.8711
#   Specificity  : 0.5029
#   AUC-ROC      : 0.8164
#
# --- Text Evaluation (Epoch 49) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
#
# Epoch 50/50
# Training loss: 6.1432
# Classification loss: 0.4445
# Generation loss: 0.6099
# Weighted gen loss: 6.098770
# Validation loss: 5.9946
# Validation metrics:
#   Accuracy     : 0.7759
#   F1-Score     : 0.7776
#   Sensitivity  : 0.8449
#   Specificity  : 0.5599
#   AUC-ROC      : 0.8156
#
# --- Text Evaluation (Epoch 50) ---
# Evaluating text generation on FULL dataset (3624 samples)
# Computing text metrics on 3624 samples...
#   METEOR Score : 0.4221
#   ROUGE-L F1   : 0.4145
# ============================================================
# TRAINING SUMMARY
# ============================================================
# Best Accuracy: 0.7906
# Best F1-Score: 0.7816
# Best AUC-ROC: 0.8167
# Best METEOR: 0.4236
# Best ROUGE-L: 0.4184
# ============================================================

# %% [markdown]
# ### Test Model and Display Text Generation Sample

# %%
test_loss_sampled, test_metrics_sampled = print_test_evaluation(model, test_loader, device, tokenizer, test_df)
# Out:
# Training completed!
# Best results from validation:
#
# ==================================================
# FINAL TEST SET EVALUATION
# ==================================================
#
# 1. Full Classification Performance:
# Test loss: 5.9471
# Classification metrics (all 3625 samples):
#   Accuracy     : 0.8011
#   F1-Score     : 0.8014
#   Sensitivity  : 0.8672
#   Specificity  : 0.5936
#   AUC-ROC      : 0.8346
#
# 2. Sampled Text Generation Performance:
# Evaluating text generation on FULL dataset (3625 samples)
# Computing text metrics on 3625 samples...
# Text generation metrics (3625 samples):
#   ROUGE-L F1   : 0.4130
#   METEOR       : 0.4206
#
# Sample efficiency: 3625/3625 samples used for text metrics

# %%
display_generated_texts(test_metrics_sampled['generated_texts'], test_metrics_sampled['reference_texts'], num_samples=20)
# Out:
# Displaying 20 randomly selected text generation samples:
#
# Sample 2620
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature values are not exceeded, and there are no signs of locally increased metabolism in the breast tissue.
# ----------------------------------------
#
# Sample 457
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrical, with asymmetry this time exceeding the recommended values. We recommend that the lady undergo an early breast scan check in 6-7 months (08-09.2019) and regularly perform self-examinations. She will also have physiotherapy for the cervical spine.
# ----------------------------------------
#
# Sample 103
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examinations once a month, regular control clinical examinations, and a repeat breast scan measurement in one year.
# ----------------------------------------
#
# Sample 3038
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The values of the measured temperature are at the upper limit of the recommended values.
# ----------------------------------------
#
# Sample 1127
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The temperature level is completely higher than the recommended value, surface asymmetry has been exceeded, but its distribution currently does not indicate signs of locally increased metabolism in the breast tissue. A follow-up is recommended in one year (02.2016). During this period, regular self-examination and preventive
# ----------------------------------------
#
# Sample 1004
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : Values of the measured temperature are currently exceeded.
# ----------------------------------------
#
# Sample 915
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# ----------------------------------------
#
# Sample 572
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrically distributed, the asymmetry is exceeded, but its distribution does not indicate signs of locally higher metabolism in breast tissue. We recommend monitoring the temperature for 1 year (06.2019). During this period, we advise regular self-examination; as an additional preventive
# ----------------------------------------
#
# Sample 3017
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The temperature is asymmetrically distributed and higher than the recommended temperature level. The right breast is completely warmer compared to the left. I advise an immediate clinical examination by a specialist oncologist and expanded diagnostics. In the case of continued monitoring of the disease, I recommend regular follow-up measurements
# ----------------------------------------
#
# Sample 420
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally elevated metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# ----------------------------------------
#
# Sample 2772
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I recommend regular self-examination and a repeat breast scan measurement in two years. In case of noticeable visible changes or prolonged pain, I advise a clinical examination by a specialist and an early measurement.
# ----------------------------------------
#
# Sample 3034
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrical, the level slightly higher, the asymmetry exceeded, but its distribution currently does not indicate signs of locally higher metabolism in breast tissue. We advise regular self-examination and comparative control in 6-8 months (10th-12th 2017), if possible on the
# ----------------------------------------
#
# Sample 2234
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature values are at the upper limit of the recommended range; the left breast is still entirely warmer (similar to the measurement from 2007), and currently, there are no significant signs of locally elevated metabolism in the breast tissue. We recommend the next breastscan measurement no later than 1 year from now (06.
# ----------------------------------------
#
# Sample 357
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. I advise regular self-examination and a repeat breast scan measurement in one year. In case of palpable, visible changes or persistent pain, I recommend a clinical examination by a specialist doctor and an earlier measurement
# ----------------------------------------
#
# Sample 2419
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The temperature distribution is symmetrical. No signs of local hyperthermia in the breasts are detected. I recommend regular self-examination once a month and a systematic check-up in one year.
# ----------------------------------------
#
# Sample 1729
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrically distributed, but its distribution currently does not indicate signs of locally elevated metabolism in the breast tissue. We recommend a follow-up breast scan in 1 year (August 2015). During this period, the lady will perform self-examinations and undergo a ma
# ----------------------------------------
#
# Sample 131
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature is asymmetrically distributed. The maximum temperature asymmetry was measured in the external superior quadrant (from +1.1 to +1.2 degrees). I recommend repeating the breast scan measurement in 6 months. In case of significant changes or prolonged pain, please contact us sooner as agreed.
# ----------------------------------------
#
# Sample 123
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature in the breast tissue is asymmetrically distributed, with values on the surface exceeding the recommended limit; however, its distribution does not currently indicate signs of locally increased metabolism. We recommend a comparative follow-up in 6-8 months (08-10.2011). During this period, we
# ----------------------------------------
#
# Sample 384
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The 2nd level and the distribution of measured temperatures do not indicate signs of locally elevated metabolism in the breast tissue. A follow-up is recommended in 1 year (06. 2019). During this period, we advise regular self-examination. In the case of noticeable, visible changes, discharge, or prolonged
# ----------------------------------------
#
# Sample 896
# ----------------------------------------
# Generated : The measured temperature does not indicate signs of locally increased metabolism in the breast tissue. We recommend regular self-examination and a follow-up breast scan measurement in one year. In case of noticeable, visible changes, discharge, or prolonged pain, we recommend a clinical examination by a specialist doctor and
# Reference : The measured temperature does not indicate signs of locally increased metabolism in breast tissue. I recommend regular self-examination and a repeat breast scan measurement in one year. In the case of palpable, visible changes, discharge, or prolonged pain, I advise a clinical examination by a specialist doctor and
# ----------------------------------------
